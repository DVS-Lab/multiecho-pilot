# %%
import os
import json
import subprocess
import glob

# %%
subjects_file="/ZPOOL/data/projects/multiecho-pilot/code/sublist-test.txt"

#def list_scans(subjects_file):
with open(subjects_file, 'r') as f:
    subjects = f.read().splitlines()
    print(subjects)
    
for subject in subjects:
    subject_path = "/ZPOOL/data/sourcedata/sourcedata/rf1-sequence-pilot/Smith-SRA-" + subject + "/Smith-SRA-" + subject + "/scans"
    print("Subject path:", subject_path)
    result = subprocess.run(['ls', '-lrt'], cwd=subject_path, capture_output=True, text=True)
    lines = result.stdout.split('\n')
    for line in lines:
        if line:
            last_column = line.split()[-1]
            print(last_column)
    print("----------------------------------------------------\n")
# Out:
# ['10054', '10186']
# Subject path: /ZPOOL/data/sourcedata/sourcedata/rf1-sequence-pilot/Smith-SRA-10054/Smith-SRA-10054/scans
# 14
# 1-localizer
# 2-T1w_anat_mpg_07sag_iso
# 3-T1w_anat_mpg_07sag_iso
# 4-fmap_gre_field_mapping_2p8iso
# 5-fmap_gre_field_mapping_2p8iso
# 6-fmap_gre_field_mapping_2p8iso
# 7-CMRR_MB1_IP0_ME1_TR1700
# 8-CMRR_MB3_IP0_ME1_TR1700_SBRef
# 9-CMRR_MB3_IP0_ME1_TR1700
# 10-CMRR_MB6_IP0_ME1_TR1700_SBRef
# 11-CMRR_MB6_IP0_ME1_TR1700
# 12-fmap_gre_field_mapping_2p8iso
# 13-fmap_gre_field_mapping_2p8iso
# 14-fmap_gre_field_mapping_2p8iso
# 15-CMRR_MB1_IP2_ME4_TR1700
# 16-CMRR_MB1_IP2_ME4_TR1700
# 17-localizer
# 18-fmap_gre_field_mapping_2p8iso
# 19-fmap_gre_field_mapping_2p8iso
# 20-fmap_gre_field_mapping_2p8iso
# 21-CMRR_MB3_IP2_ME4_TR1700_SBRef
# 22-CMRR_MB3_IP2_ME4_TR1700
# 23-CMRR_MB3_IP2_ME4_TR1700
# 24-CMRR_MB6_IP2_ME4_TR1700_SBRef
# 25-CMRR_MB6_IP2_ME4_TR1700
# 26-CMRR_MB6_IP2_ME4_TR1700
# 99-PhoenixZIPReport
# ----------------------------------------------------
#
# Subject path: /ZPOOL/data/sourcedata/sourcedata/rf1-sequence-pilot/Smith-SRA-10186/Smith-SRA-10186/scans
# 15
# 1-localizer
# 2-T1w_anat_mpg_07sag_iso
# 3-T1w_anat_mpg_07sag_iso
# 4-fmap_gre_field_mapping_2p8iso
# 5-fmap_gre_field_mapping_2p8iso
# 6-fmap_gre_field_mapping_2p8iso
# 7-CMRR_MB6_IP0_ME1_TR1700_SBRef
# 8-CMRR_MB6_IP0_ME1_TR1700
# 9-CMRR_MB1_IP2_ME4_TR1700
# 10-CMRR_MB1_IP2_ME4_TR1700
# 11-CMRR_MB1_IP2_ME4_TR1700
# 12-CMRR_MB1_IP2_ME4_TR1700
# 13-CMRR_MB3_IP2_ME4_TR1700_SBRef
# 14-CMRR_MB3_IP2_ME4_TR1700
# 15-CMRR_MB3_IP2_ME4_TR1700
# 16-fmap_gre_field_mapping_2p8iso
# 17-fmap_gre_field_mapping_2p8iso
# 18-fmap_gre_field_mapping_2p8iso
# 19-localizer
# 20-fmap_gre_field_mapping_2p8iso
# 21-fmap_gre_field_mapping_2p8iso
# 22-fmap_gre_field_mapping_2p8iso
# 23-CMRR_MB6_IP2_ME4_TR1700_SBRef
# 24-CMRR_MB6_IP2_ME4_TR1700
# 25-CMRR_MB6_IP2_ME4_TR1700
# 26-CMRR_MB1_IP0_ME1_TR1700
# 28-CMRR_MB3_IP0_ME1_TR1700
# 27-CMRR_MB3_IP0_ME1_TR1700_SBRef
# 99-PhoenixZIPReport
# ----------------------------------------------------

# %%
for subject in subjects:
    subject_path = "/ZPOOL/data/sourcedata/sourcedata/rf1-sequence-pilot/Smith-SRA-" + subject + "/Smith-SRA-" + subject + "/scans"
    print("Subject path:", subject_path)
    result = subprocess.run(['ls', '-lrt'], cwd=subject_path, capture_output=True, text=True)
    lines = result.stdout.split('\n')

    fmap_count = 0
    fmap_sequence = 0
    prev_fmap_run = None
    for line in lines:
        if line:
            last_column = line.split()[-1]
            if "fmap" in last_column:
                fmap_sequence += 1
                if fmap_sequence == 1:
                    fmap_count += 1
                prev_fmap_run = f"fmap_run-{fmap_count}"
                print(f"{last_column} is {prev_fmap_run}")
            else:
                fmap_sequence = 0
    print("----------------------------------------------------\n")
# Out:
# Subject path: /ZPOOL/data/sourcedata/sourcedata/rf1-sequence-pilot/Smith-SRA-10054/Smith-SRA-10054/scans
# 4-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 5-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 6-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 12-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 13-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 14-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 18-fmap_gre_field_mapping_2p8iso is fmap_run-3
# 19-fmap_gre_field_mapping_2p8iso is fmap_run-3
# 20-fmap_gre_field_mapping_2p8iso is fmap_run-3
# ----------------------------------------------------
#
# Subject path: /ZPOOL/data/sourcedata/sourcedata/rf1-sequence-pilot/Smith-SRA-10186/Smith-SRA-10186/scans
# 4-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 5-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 6-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 16-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 17-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 18-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 20-fmap_gre_field_mapping_2p8iso is fmap_run-3
# 21-fmap_gre_field_mapping_2p8iso is fmap_run-3
# 22-fmap_gre_field_mapping_2p8iso is fmap_run-3
# ----------------------------------------------------

# %%
for subject in subjects:
    subject_path = "/ZPOOL/data/sourcedata/sourcedata/rf1-sequence-pilot/Smith-SRA-" + subject + "/Smith-SRA-" + subject + "/scans"
    print("Subject path:", subject_path)
    result = subprocess.run(['ls', '-lrt'], cwd=subject_path, capture_output=True, text=True)
    lines = result.stdout.split('\n')
    
    fmap_count = 0
    fmap_sequence = 0
    prev_fmap_run = None
    functional_runs = []
    for line in lines:
        if line:
            last_column = line.split()[-1]
            if "fmap" in last_column:
                fmap_sequence += 1
                if fmap_sequence == 1:
                    fmap_count += 1
                prev_fmap_run = f"fmap_run-{fmap_count}"
                print(f"{last_column} is {prev_fmap_run}")
            elif "CMRR" in last_column:
                functional_runs.append(last_column)
                if prev_fmap_run:
                    mb_value = [int(s[2:]) for s in last_column.split("_") if "MB" in s][0]
                    me_value = [int(s[2:]) for s in last_column.split("_") if "ME" in s][0]
                    #print(f"Intended for {prev_fmap_run}: {last_column} (MB={mb_value}, ME={me_value})")
                    if me_value == 4:
                        print(f"sub-{subject}_task-sharedreward_acq-mb{mb_value}me4_echo-1_part-mag_bold.nii.gz")
                        print(f"sub-{subject}_task-sharedreward_acq-mb{mb_value}me4_echo-1_part-phase_bold.nii.gz")
                        print(f"sub-{subject}_task-sharedreward_acq-mb{mb_value}me4_echo-2_part-mag_bold.nii.gz")
                        print(f"sub-{subject}_task-sharedreward_acq-mb{mb_value}me4_echo-2_part-phase_bold.nii.gz")
                        print(f"sub-{subject}_task-sharedreward_acq-mb{mb_value}me4_echo-3_part-mag_bold.nii.gz")
                        print(f"sub-{subject}_task-sharedreward_acq-mb{mb_value}me4_echo-3_part-phase_bold.nii.gz")
                        print(f"sub-{subject}_task-sharedreward_acq-mb{mb_value}me4_echo-4_part-mag_bold.nii.gz")
                        print(f"sub-{subject}_task-sharedreward_acq-mb{mb_value}me4_echo-4_part-phase_bold.nii.gz")
                    else:
                        print(f"sub-{subject}_task-sharedreward_acq-mb{mb_value}me1_bold.nii.gz")
            else:
                fmap_sequence = 0
    print("----------------------------------------------------\n")
# Out:
# Subject path: /ZPOOL/data/sourcedata/sourcedata/rf1-sequence-pilot/Smith-SRA-10054/Smith-SRA-10054/scans
# 4-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 5-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 6-fmap_gre_field_mapping_2p8iso is fmap_run-1
# sub-10054_task-sharedreward_acq-mb1me1_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me1_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me1_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me1_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me1_bold.nii.gz
# 12-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 13-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 14-fmap_gre_field_mapping_2p8iso is fmap_run-1
# sub-10054_task-sharedreward_acq-mb1me4_echo-1_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-1_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-2_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-2_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-3_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-3_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-4_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-4_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-1_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-1_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-2_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-2_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-3_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-3_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-4_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb1me4_echo-4_part-phase_bold.nii.gz
# 18-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 19-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 20-fmap_gre_field_mapping_2p8iso is fmap_run-2
# sub-10054_task-sharedreward_acq-mb3me4_echo-1_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-1_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-2_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-2_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-3_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-3_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-4_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-4_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-1_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-1_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-2_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-2_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-3_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-3_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-4_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-4_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-1_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-1_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-2_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-2_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-3_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-3_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-4_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb3me4_echo-4_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-1_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-1_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-2_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-2_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-3_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-3_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-4_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-4_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-1_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-1_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-2_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-2_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-3_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-3_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-4_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-4_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-1_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-1_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-2_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-2_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-3_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-3_part-phase_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-4_part-mag_bold.nii.gz
# sub-10054_task-sharedreward_acq-mb6me4_echo-4_part-phase_bold.nii.gz
# ----------------------------------------------------
#
# Subject path: /ZPOOL/data/sourcedata/sourcedata/rf1-sequence-pilot/Smith-SRA-10186/Smith-SRA-10186/scans
# 4-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 5-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 6-fmap_gre_field_mapping_2p8iso is fmap_run-1
# sub-10186_task-sharedreward_acq-mb6me1_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me1_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-1_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-1_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-2_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-2_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-3_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-3_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-4_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-4_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-1_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-1_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-2_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-2_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-3_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-3_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-4_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-4_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-1_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-1_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-2_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-2_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-3_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-3_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-4_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-4_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-1_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-1_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-2_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-2_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-3_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-3_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-4_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me4_echo-4_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-1_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-1_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-2_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-2_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-3_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-3_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-4_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-4_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-1_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-1_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-2_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-2_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-3_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-3_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-4_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-4_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-1_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-1_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-2_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-2_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-3_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-3_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-4_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me4_echo-4_part-phase_bold.nii.gz
# 16-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 17-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 18-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 20-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 21-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 22-fmap_gre_field_mapping_2p8iso is fmap_run-2
# sub-10186_task-sharedreward_acq-mb6me4_echo-1_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-1_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-2_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-2_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-3_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-3_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-4_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-4_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-1_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-1_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-2_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-2_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-3_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-3_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-4_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-4_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-1_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-1_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-2_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-2_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-3_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-3_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-4_part-mag_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb6me4_echo-4_part-phase_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb1me1_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me1_bold.nii.gz
# sub-10186_task-sharedreward_acq-mb3me1_bold.nii.gz
# ----------------------------------------------------

# %%
for subject in subjects:
    subject_path = "/ZPOOL/data/sourcedata/sourcedata/rf1-sequence-pilot/Smith-SRA-" + subject + "/Smith-SRA-" + subject + "/scans"
    print("Subject path:", subject_path)
    result = subprocess.run(['ls', '-lrt'], cwd=subject_path, capture_output=True, text=True)
    lines = result.stdout.split('\n')
    
    fmap_count = 0
    fmap_sequence = 0
    prev_fmap_run = None
    functional_runs = []
    
    for line in lines:
        if line:
            last_column = line.split()[-1]
            if "fmap" in last_column:
                fmap_sequence += 1
                if fmap_sequence == 1:
                    fmap_count += 1
                prev_fmap_run = f"fmap_run-{fmap_count}"
                print(f"{last_column} is {prev_fmap_run}")
            elif "CMRR" in last_column:
                functional_runs.append(last_column)
            else:
                if prev_fmap_run:
                    for i in range(1, 4):
                        print(f"sub-{subject}_acq-bold_run-{prev_fmap_run[-1]}_magnitude{i}.json")
                prev_fmap_run = None
                fmap_sequence = 0
                
    print("Functional runs intended for this subject:")
    for run in functional_runs:
        print(run)
    print("----------------------------------------------------\n")
# Out:
# Subject path: /ZPOOL/data/sourcedata/sourcedata/rf1-sequence-pilot/Smith-SRA-10054/Smith-SRA-10054/scans
# 4-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 5-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 6-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 12-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 13-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 14-fmap_gre_field_mapping_2p8iso is fmap_run-1
# sub-10054_acq-bold_run-1_magnitude1.json
# sub-10054_acq-bold_run-1_magnitude2.json
# sub-10054_acq-bold_run-1_magnitude3.json
# 18-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 19-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 20-fmap_gre_field_mapping_2p8iso is fmap_run-2
# sub-10054_acq-bold_run-2_magnitude1.json
# sub-10054_acq-bold_run-2_magnitude2.json
# sub-10054_acq-bold_run-2_magnitude3.json
# Functional runs intended for this subject:
# 7-CMRR_MB1_IP0_ME1_TR1700
# 8-CMRR_MB3_IP0_ME1_TR1700_SBRef
# 9-CMRR_MB3_IP0_ME1_TR1700
# 10-CMRR_MB6_IP0_ME1_TR1700_SBRef
# 11-CMRR_MB6_IP0_ME1_TR1700
# 15-CMRR_MB1_IP2_ME4_TR1700
# 16-CMRR_MB1_IP2_ME4_TR1700
# 21-CMRR_MB3_IP2_ME4_TR1700_SBRef
# 22-CMRR_MB3_IP2_ME4_TR1700
# 23-CMRR_MB3_IP2_ME4_TR1700
# 24-CMRR_MB6_IP2_ME4_TR1700_SBRef
# 25-CMRR_MB6_IP2_ME4_TR1700
# 26-CMRR_MB6_IP2_ME4_TR1700
# ----------------------------------------------------
#
# Subject path: /ZPOOL/data/sourcedata/sourcedata/rf1-sequence-pilot/Smith-SRA-10186/Smith-SRA-10186/scans
# 4-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 5-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 6-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 16-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 17-fmap_gre_field_mapping_2p8iso is fmap_run-1
# 18-fmap_gre_field_mapping_2p8iso is fmap_run-1
# sub-10186_acq-bold_run-1_magnitude1.json
# sub-10186_acq-bold_run-1_magnitude2.json
# sub-10186_acq-bold_run-1_magnitude3.json
# 20-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 21-fmap_gre_field_mapping_2p8iso is fmap_run-2
# 22-fmap_gre_field_mapping_2p8iso is fmap_run-2
# sub-10186_acq-bold_run-2_magnitude1.json
# sub-10186_acq-bold_run-2_magnitude2.json
# sub-10186_acq-bold_run-2_magnitude3.json
# Functional runs intended for this subject:
# 7-CMRR_MB6_IP0_ME1_TR1700_SBRef
# 8-CMRR_MB6_IP0_ME1_TR1700
# 9-CMRR_MB1_IP2_ME4_TR1700
# 10-CMRR_MB1_IP2_ME4_TR1700
# 11-CMRR_MB1_IP2_ME4_TR1700
# 12-CMRR_MB1_IP2_ME4_TR1700
# 13-CMRR_MB3_IP2_ME4_TR1700_SBRef
# 14-CMRR_MB3_IP2_ME4_TR1700
# 15-CMRR_MB3_IP2_ME4_TR1700
# 23-CMRR_MB6_IP2_ME4_TR1700_SBRef
# 24-CMRR_MB6_IP2_ME4_TR1700
# 25-CMRR_MB6_IP2_ME4_TR1700
# 26-CMRR_MB1_IP0_ME1_TR1700
# 28-CMRR_MB3_IP0_ME1_TR1700
# 27-CMRR_MB3_IP0_ME1_TR1700_SBRef
# ----------------------------------------------------

# %%
# Main script kernel

# Read subject IDs from a text file
subjects_file = '/ZPOOL/data/projects/multiecho-pilot/code/sublist-test.txt'
with open(subjects_file, 'r') as f:
    subjects = f.read().splitlines()

# Process each subject
for subject in subjects:
    print(f"Processing subject {subject}...")
    
    # Get the subject directories
    subject_dirs = glob.glob(f"/ZPOOL/data/sourcedata/sourcedata/rf1-sequence-pilot/Smith-SRA-{subject}/Smith-SRA-{subject}/scans")
    
    # Initialize the scan list
    scan_list = []
    
    # Populate the scan list with ls -lrt command
    for subject_dir in subject_dirs:
        result = subprocess.run(['ls', '-lrt', subject_dir], capture_output=True, text=True)
        scan_list = result.stdout.splitlines()[1:] # Ignore the first line (total)
    #print("/n".join(scan_list)) # Print the scan list for debugging purposes
    
    # Initialize vars
    fmap_count = 0
    fmap_sequence = 0
    prev_fmap_run = None
    functional_runs = []
    fmap_runs = {}
    
    # Process each line in the scan list
    for line in scan_list:
        last_column = line.split()[-1]
        
        # Check if the line contains a fieldmap scan
        if "fmap" in last_column:
            fmap_sequence += 1
            if fmap_sequence == 1:
                fmap_count += 1
                fmap_runs[f"fmap_run-{fmap_count}"] = []
            prev_fmap_run = f"fmap_run-{fmap_count}"
            #print(f"{last_column} is {prev_fmap_run}")
            
            # Reset fmap_sequence after the third fmap
            if fmap_sequence == 3:
                fmap_sequence = 0
        
        # Check if the line contains a functional scan
        elif "CMRR" in last_column:
            functional_runs.append(last_column)
            if prev_fmap_run:
                mb_index = last_column.find("MB")
                me_index = last_column.find("ME")
                mb_value = last_column[mb_index:mb_index + 3].lower() # Extract MB value and convert to lowercase
                me_value = last_column[me_index:me_index + 3].lower() # Extract ME value and convert to lowercase
                mb_me_combination = f"{mb_value}{me_value}"
                if mb_me_combination not in fmap_runs[prev_fmap_run]:
                    fmap_runs[prev_fmap_run].append(mb_me_combination)
                #print(f"Intended for {prev_fmap_run}: {last_column}")
                #print(f"MB={mb_value[2]}, ME={me_value[2]}")
                #print(f"Current combinations for {prev_fmap_run}: {fmap_runs[prev_fmap_run]}")
                
        
        # Reset the sequence if the line is neither a fmap nor functional run:
        else:
            fmap_sequence = 0
    
    #print(f"Final fmap runs for subject {subject}: {fmap_runs}")
    #print("\n")

    # Create separate lists for each fmap_run
    fmap_run_lists = {}
    for fmap_run, mb_me_combinations in fmap_runs.items():
        fmap_run_lists[f"{fmap_run}_func"] = mb_me_combinations

    # Print the parsed lists for each fmap_run
    for fmap_run, combinations in fmap_run_lists.items():
        print(f"{fmap_run}: {combinations}")
        
    # Define the base directory for the JSON files
    json_base_dir = f"/ZPOOL/data/projects/multiecho-pilot/bids/sub-{subject}/fmap"
    
    # Update JSON files based on fmap_run_lists
    for fmap_run, mb_me_combinations in fmap_run_lists.items():
        # Skip if combinations is empty
        if not mb_me_combinations:
            continue
        
        # Extract run number
        run_number = fmap_run.split('-')[1].split('_')[0]

        # Define JSON file paths for the current fmap_run
        magnitude1_json = os.path.join(json_base_dir, f"sub-{subject}_acq-bold_run-{run_number}_magnitude1.json")
        magnitude2_json = os.path.join(json_base_dir, f"sub-{subject}_acq-bold_run-{run_number}_magnitude2.json")
        phasediff_json = os.path.join(json_base_dir, f"sub-{subject}_acq-bold_run-{run_number}_phasediff.json")

        # List of JSON files to update
        json_files = [magnitude1_json, magnitude2_json, phasediff_json]

        # Collect all intended functional runs
        intended_for = []

        for mb_me_combination in mb_me_combinations:
            mb = mb_me_combination[:3]  # Extract mb part
            me = mb_me_combination[3:]  # Extract me part
            
            if me == "me1":
                intended_for.append(f"func/sub-{subject}_task-sharedreward_acq-{mb}{me}_bold.nii.gz")
            elif me == "me4":
                for echo in range(1, 5):
                    intended_for.append(f"func/sub-{subject}_task-sharedreward_acq-{mb}{me}_echo-{echo}_phasediff.nii.gz")
                    intended_for.append(f"func/sub-{subject}_task-sharedreward_acq-{mb}{me}_echo-{echo}_magnitude.nii.gz")

        # Update each JSON file with the intended functional runs
        for json_file in json_files:
            #print(f"{json_file}")
            if os.path.exists(json_file):
                with open(json_file, 'r') as f:
                    json_data = json.load(f)
                
                intended_for = []
                for comb in mb_me_combinations:
                    mb = comb.split('me')[0][2:]
                    me = comb.split('me')[1]
                    
                    if me == '1':
                        intended_for.append(f"func/sub-{subject}_task-sharedreward_acq-mb{mb}me1_bold.nii.gz")
                    elif me == '4':
                        intended_for.extend([
                            f"func/sub-{subject}_task-sharedreward_acq-mb{mb}me4_echo-1_phasediff.nii.gz",
                            f"func/sub-{subject}_task-sharedreward_acq-mb{mb}me4_echo-1_magnitude.nii.gz",
                            f"func/sub-{subject}_task-sharedreward_acq-mb{mb}me4_echo-2_phasediff.nii.gz",
                            f"func/sub-{subject}_task-sharedreward_acq-mb{mb}me4_echo-2_magnitude.nii.gz",
                            f"func/sub-{subject}_task-sharedreward_acq-mb{mb}me4_echo-3_phasediff.nii.gz",
                            f"func/sub-{subject}_task-sharedreward_acq-mb{mb}me4_echo-3_magnitude.nii.gz",
                            f"func/sub-{subject}_task-sharedreward_acq-mb{mb}me4_echo-4_phasediff.nii.gz",
                            f"func/sub-{subject}_task-sharedreward_acq-mb{mb}me4_echo-4_magnitude.nii.gz"
                        ])
                
                # Overwrite the 'IntendedFor' field
                json_data['IntendedFor'] = intended_for

                # Print changes
                print(f"Updating {json_file}: IntendedFor -> {intended_for}")
                
                # Write back to the JSON file
                with open(json_file, 'w') as f:
                    json.dump(json_data, f, indent=4)
            else:
                print(f"JSON file {json_file} not found.")
    
print("Processing completed.")
# Out:
# Processing subject 10054...
# fmap_run-1_func: ['mb1me1', 'mb3me1', 'mb6me1']
# fmap_run-2_func: ['mb1me4']
# fmap_run-3_func: ['mb3me4', 'mb6me4']
# Updating /ZPOOL/data/projects/multiecho-pilot/bids/sub-10054/fmap/sub-10054_acq-bold_run-1_magnitude1.json: IntendedFor -> ['func/sub-10054_task-sharedreward_acq-mb1me1_bold.nii.gz', 'func/sub-10054_task-sharedreward_acq-mb3me1_bold.nii.gz', 'func/sub-10054_task-sharedreward_acq-mb6me1_bold.nii.gz']
# Updating /ZPOOL/data/projects/multiecho-pilot/bids/sub-10054/fmap/sub-10054_acq-bold_run-1_magnitude2.json: IntendedFor -> ['func/sub-10054_task-sharedreward_acq-mb1me1_bold.nii.gz', 'func/sub-10054_task-sharedreward_acq-mb3me1_bold.nii.gz', 'func/sub-10054_task-sharedreward_acq-mb6me1_bold.nii.gz']
# Updating /ZPOOL/data/projects/multiecho-pilot/bids/sub-10054/fmap/sub-10054_acq-bold_run-1_phasediff.json: IntendedFor -> ['func/sub-10054_task-sharedreward_acq-mb1me1_bold.nii.gz', 'func/sub-10054_task-sharedreward_acq-mb3me1_bold.nii.gz', 'func/sub-10054_task-sharedreward_acq-mb6me1_bold.nii.gz']
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[6], line 119
#     117 if os.path.exists(json_file):
#     118     with open(json_file, 'r') as f:
# --> 119         json_data = json.load(f)
#     121     intended_for = []
#     122     for comb in mb_me_combinations:
#
# File /ZPOOL/data/tools/anaconda/tun46412/anaconda3/lib/python3.11/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File /ZPOOL/data/tools/anaconda/tun46412/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /ZPOOL/data/tools/anaconda/tun46412/anaconda3/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /ZPOOL/data/tools/anaconda/tun46412/anaconda3/lib/python3.11/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 40 column 1 (char 1556)

# %%
fmap_run_lists.items()
for fmap_run, combinations in fmap_run_lists.items():
    run_number = fmap_run.split('-')[1].split('_')[0]
    print(f"Run number: {run_number}")
